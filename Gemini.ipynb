# %%
import numpy as np
import pandas as pd
import requests
import pyodbc

# %%
conn = pyodbc.connect('driver={SQL Server};server=R90QPYP5\SQLSERVER2016;database=master')
cursor = conn.cursor()

##database creation
sql_file = open("SQLScriptForDBCreation.sql")
sql_as_string = sql_file.read()

cursor.execute(sql_as_string)
conn.commit()
conn.close()
###table creation

# %%
conn2 = pyodbc.connect('driver={SQL Server};server=R90QPYP5\SQLSERVER2016;database=Netflix_datastorage')
cursor2 = conn2.cursor()
sql_file2 = open("SQLScriptForTablesCreation.sql")
sql_as_string2 = sql_file2.read()
#sql_as_string
cursor2.execute(sql_as_string2)



conn2.commit()
conn2.close()

# %%
netflix_csv = pd.read_csv('netflix_titles.csv')
netflix_csv
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
count=0
def checkcount(x):
    x =1

checkcount(count)

# %%
conn = pyodbc.connect('driver={SQL Server};server=R90QPYP5\SQLSERVER2016;database=Netflix_datastorage')
cursor = conn.cursor()


for x in netflix_csv['description']:
    cursor.execute('''
            INSERT INTO Description (DescriptionID,Description)
            VALUES (?,?)
            ''',
            count,  
            str(x)
            )
    count=count +1
    

checkcount(count)  

for x in netflix_csv['type']:
    cursor.execute('''
            INSERT INTO Type (TypeID,TypeName)
            VALUES (?,?)
            ''',
            count,  
            str(x)
             )
    count=count +1
    
checkcount(count)
for x in netflix_csv['listed_in']:
    cursor.execute('''
            INSERT INTO ShowListing (ListingID,ShowListing)
            VALUES (?,?)
            ''',
            count,  
            str(x)
            )
    count=count +1
    
checkcount(count)

for x in netflix_csv['rating']:
    cursor.execute('''
            INSERT INTO Rating (RatingID,RatingName)
            VALUES (?,?)
            ''',
            count,  
            str(x)
            )
    count=count+1
    
checkcount(count)
for x in netflix_csv['duration']:
    cursor.execute('''
            INSERT INTO ShowDuration (DurationID,Duration)
            VALUES (?,?)
            ''',
            count,  
            str(x)
            )
    count=count +1
    
checkcount(count)
for x in netflix_csv['country']:
    cursor.execute('''
            INSERT INTO Country (CountryID,CountryName)
            VALUES (?,?)
            ''',
            count,  
            str(x)
            )
    count=count +1
checkcount(count)
for x in netflix_csv['director']:
    cursor.execute('''
            INSERT INTO Director (DirectorID,DirectorName)
            VALUES (?,?)
            ''',
            count,  
            str(x)
            )
    count=count +1


conn.commit()
conn.close()

# %%
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-88-8c176195907a> in <module>
#       9 for row in showlisting:
#      10
# ---> 11     cursor.execute('''
#      12                 INSERT INTO ShowListing (ListingID,ShowListing)
#      13                 VALUES (?,?)
#
# IntegrityError: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK_ShowListing'. Cannot insert duplicate key in object 'dbo.ShowListing'. The duplicate key value is (1). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")

# %%
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-90-8d530b285bd2> in <module>
#       9 for row in type:
#      10
# ---> 11     cursor.execute('''
#      12                 INSERT INTO Type (TypeID,TypeName)
#      13                 VALUES (?,?)
#
# IntegrityError: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK_Type'. Cannot insert duplicate key in object 'dbo.Type'. The duplicate key value is (1). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")

# %%
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-128-4521da5f0776> in <module>
#      39
#      40 for x in netflix_csv['rating']:
# ---> 41     cursor.execute('''
#      42             INSERT INTO Rating (RatingID,RatingName)
#      43             VALUES (?,?)
#
# IntegrityError: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK_Rating'. Cannot insert duplicate key in object 'dbo.Rating'. The duplicate key value is (46723). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
